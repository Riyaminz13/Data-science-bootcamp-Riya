# %%
# 14
def unique (ls):
    # unique_ele = []
    # for i in ls:
    #     if i not in unique_ele:
    #         unique_ele.append(i)
    # return unique_ele

    return list({x for x in ls if ls.count(x)== 1})
ls = [1,2,3,4,4,5,6]
print(unique(ls))
# Out:
# [1, 2, 3, 5, 6]

# %%
def dups (ls):
    return list({x for x in ls if ls.count(x) > 1})

ls = [1,2,2,3,4,4,4,5,6]
print(dups(ls))
# Out:
# [2, 4]
