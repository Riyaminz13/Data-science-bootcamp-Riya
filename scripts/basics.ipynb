# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
os.getcwd()
# Out:
# 'd:\\my_my\\data science\\scripts'

# %%
H_M = pd.read_csv('D:\\my_my\\data science\\datasets\\handm.csv')

# print(H_M)

# H_M.head()
# H_M.tail()
# H_M.shape
# H_M.columns
H_M.info()
# H_M.describe
# H_M.isnull().sum() # tell the count of null values columm vise
# H_M.isnull().values.any() # tell if there is any null value present
# H_M.isna().sum()
# H_M.isnull().sum().sum() # tell total null value number
# (H_M.isnull().sum()/len(H_M))*100 #tell percentage of null values
# H_M[H_M.isnull().any(axis=1)]
# H_M.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9677 entries, 0 to 9676
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   9677 non-null   int64
#  1   productId    9677 non-null   int64
#  2   productName  9677 non-null   object
#  3   brandName    9677 non-null   object
#  4   url          9677 non-null   object
#  5   price        9677 non-null   float64
#  6   stockState   9677 non-null   object
#  7   comingSoon   9677 non-null   bool
#  8   colorName    9677 non-null   object
#  9   isOnline     9677 non-null   bool
#  10  colors       9677 non-null   object
#  11  colorShades  6511 non-null   object
#  12  newArrival   9677 non-null   bool
#  13  mainCatCode  9677 non-null   object
#  14  details      9676 non-null   object
#  15  materials    9518 non-null   object
# dtypes: bool(3), float64(1), int64(2), object(10)
# memory usage: 1011.3+ KB

# %%
H_M['price'] = H_M['price'].astype('float32')
H_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9677 entries, 0 to 9676
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   9677 non-null   int64
#  1   productId    9677 non-null   int64
#  2   productName  9677 non-null   object
#  3   brandName    9677 non-null   object
#  4   url          9677 non-null   object
#  5   price        9677 non-null   float32
#  6   stockState   9677 non-null   object
#  7   comingSoon   9677 non-null   bool
#  8   colorName    9677 non-null   object
#  9   isOnline     9677 non-null   bool
#  10  colors       9677 non-null   object
#  11  colorShades  6511 non-null   object
#  12  newArrival   9677 non-null   bool
#  13  mainCatCode  9677 non-null   object
#  14  details      9676 non-null   object
#  15  materials    9518 non-null   object
# dtypes: bool(3), float32(1), int64(2), object(10)
# memory usage: 973.5+ KB

# %%
# filtering data 

H_M[(H_M['price'] > 50) & H_M['productName'].str.contains('jean',case=False, na=False)] 
Query=H_M.query("price >= 50 and stockState == 'Available'")

# %%
# plot 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

plt.plot(H_M['price'])
plt.title('isOnline  trend')
# Out:
# Text(0.5, 1.0, 'isOnline  trend')

# %%
plt.hist(H_M['price'], bins = 50, log=True)
# Out:
# (array([1.225e+03, 2.318e+03, 1.907e+03, 2.181e+03, 8.520e+02, 1.200e+02,
#         4.360e+02, 2.180e+02, 1.260e+02, 7.600e+01, 4.200e+01, 0.000e+00,
#         3.900e+01, 7.000e+00, 1.200e+01, 1.700e+01, 1.000e+01, 1.600e+01,
#         1.000e+01, 1.000e+00, 1.500e+01, 0.000e+00, 4.000e+00, 0.000e+00,
#         2.400e+01, 1.000e+00, 0.000e+00, 5.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 4.000e+00, 1.000e+00, 0.000e+00, 6.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  3.99  ,  13.2902,  22.5904,  31.8906,  41.1908,  50.491 ,
#          59.7912,  69.0914,  78.3916,  87.6918,  96.992 , 106.2922,
#         115.5924, 124.8926, 134.1928, 143.493 , 152.7932, 162.0934,
#         171.3936, 180.6938, 189.994 , 199.2942, 208.5944, 217.8946,
#         227.1948, 236.495 , 245.7952, 255.0954, 264.3956, 273.6958,
# ...

# %%
plt.hist(H_M['price'],bins = 30)
plt.xlabel("Price")
plt.ylabel("Number of Products")
plt.title("Price Distribution")
plt.show()

# %%
H_M['stockState'].value_counts().plot(kind='bar', color='orange')
# Out:
# <Axes: xlabel='stockState'>

# %%
sns.histplot(H_M['price'], bins=10, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.scatterplot(x='price', y='isOnline', data=H_M)
# Out:
# <Axes: xlabel='price', ylabel='isOnline'>
